# %% [markdown]
# <a href="https://colab.research.google.com/github/switlanakostyuk-ctrl/Apollo/blob/main/%22hw_9_3_%D0%A6%D0%B8%D0%BA%D0%BB_while_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до теми "Цикл while"

# %% [markdown]
# 1. **Лічильник до заданого числа.**
#    Завдання:
#      - Створіть цикл `while`, щоб він лічив від 1 до заданого числа в змінній `limit` (включно).
#      - Виведіть кожне число, яке проходить лічильник, на екран.
#      - В кінці виведіть повідомлення "Кінець розрахунку!".

# %%
limit = 9  # Задане число

# %%
counter = 1
while counter <= limit:
    print(counter)
    counter += 1

print("Кінець розрахунку!")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Кінець розрахунку!

# %% [markdown]
# 2. **Пошук першого парного числа.** Завдання:
#      - Створіть цикл `while`, щоб знайти перше парне число після заданого числа `start`.
#      - Знайдіть та виведіть перше парне число.

# %%
start = 7  # Задане число

# %%
num = start + 1
while True:
    if num % 2 == 0:
        print(num)
        break
    num += 1
# Out:
# 8

# %% [markdown]
# # НЕПАРНЕ число

# %%
num = start + 1
while True:
    if num % 2 != 0:
        print(num)
        break
    num += 1
# Out:
# 9

# %% [markdown]
# 3. **Обчислення факторіалу.**
#   Факторіал числа - це добуток всіх натуральних чисел від 1 до цього числа включно. Наприклад, факторіал числа 5 (позначається як 5!) дорівнює `1 * 2 * 3 * 4 * 5 = 120`.
#
#   Завдання:
#       - Обчисліть факторіал заданого числа, використовуючи цикл `while`.
#       - Задайте деяке число для обчислення факторіалу у змінній `num`.
#       - Виведіть обчислений факторіал на екран.

# %%
num = 5

factorial = 1
current = 1

while current <= num:
    factorial *= current
    current += 1

print(factorial)
# Out:
# 120

# %% [markdown]
# # Число в квадраті

# %%
n = 6

result = 1
counter = 0

while counter < 2:
    result *= n
    counter += 1

print(result)
# Out:
# 36

# %% [markdown]
# Площа прямокутника

# %%
a = 4
b = 7

area = 0
counter = 0

while counter < b:
    area += a
    counter += 1

print(area)
# Out:
# 28

# %% [markdown]
# # Площа квадрата через while

# %%
side = 5

area = 0
counter = 0

while counter < side:
    area += side
    counter += 1

print(area)
# Out:
# 25
